# %% [markdown]
# # Changes
#
# In version 2, the variance in the recency score and frequency wasn't a lot which basically left only the cost of the product to determine the rfm score's value and therefore the loyalty of a customer. To overcome that problem in this iteration we have combined the transactions data with a more updated version.
#
# - Combined transactions data used from year 2020 and then 2021-03 to 2021-07.
#
# #### Additions to dataframes
#
# - Consider the returns data
#
#
# #### Addition to metrics
# - While looking at the product distributions the categories each customer bought could be considered, a loyal customer is more likely to buy items from different categories
# - Satisfaction : bought more than one product on different dates and didnt return them
# - Customers buying flagship products - keep this as optional (for clients)
# - average monetary value instead of total sum
# - Optimize RFM - qcut could be lower ranged
# - When a customer jumps from one loyalty score to another (of a certain range) - what products did they buy during that time?
#
# #### Additional parameters (notes)
# - More repeat purchases
# - Higher retention
# - Higher average order value (AOV)
# - Higher engagement
# - Forgiveness for poor service
# - More vocal customer advocates

# %%
#data processing and math
import pandas as pd

#visualization
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import plotly.express as px

from datetime import datetime,timedelta

#pandas setting to see all columns and rows
pd.set_option("display.max_columns", 50)

# %%
#set path accordingly if running in your own local system and make sure you have the required data from gcp
path = '/home/td/Desktop/cerebra_clients_data/data_ridgewallet/'

# %%
#transactions data
combined_transformed_transaction_lines_df = pd.read_parquet(path+'combined_data_points/ridgewallet_parquet_files_combined_transformed_transaction_lines_part-00000-f186deaa-9bcb-4e68-ae38-810a9582b681-c000.snappy.parquet')
combined_transformed_transaction_lines_df_2 = pd.read_parquet(path+'combined_data_points/latest_combined_transaction_lines_20210301_20210708.parquet')
dfs = [combined_transformed_transaction_lines_df, combined_transformed_transaction_lines_df_2]
combined_transactions = pd.concat(dfs)

#customer data to get customer's affinity to marketing and their order count
customer_df = pd.read_json(path+'/customers/ridgewallet_raw_data_customers_customers.json')

#merchandise data for product information
merchandise_df = pd.read_parquet(path+'/combined_data_points/ridgewallet_parquet_files_combined_merchandise_part-00000-c2c7c29c-d500-45b8-b045-08a71464a5da-c000.snappy.parquet')

# %% [markdown]
# ### Cleaning the input data
#
# - Getting rid of customer ids with '#' and 'null' customer ids in transactions_df
# - Dropping columns which arent being used from customer_df and coverting customer_ids in it to int format

# %%
#dropping # and none customer_ids
combined_transactions = combined_transactions[combined_transactions['customer_id'].str.contains("#")==False]
combined_transactions = combined_transactions[combined_transactions['customer_id'].str.contains("None")==False]
combined_transactions = combined_transactions[combined_transactions['customer_id'].str.contains("nan")==False]

#actual metric file has these checks
#combined_transactions = combined_transactions[combined_transactions.customer_id != 'None']
#combined_transactions = combined_transactions[combined_transactions.customer_id != 'nan']

#dropping unnecessary columns which arent being used
"""
customer_df = customer_df.drop(['email','created_at','updated_at', 'state', 'last_order_id', 'note', 'multipass_identifier',                                
                              'tax_exempt','tags','last_order_name','currency','addresses','accepts_marketing_updated_at',
                             'marketing_opt_in_level','tax_exemptions','admin_graphql_api_id','default_address'], axis=1)
"""
#converting customer_id and product_id to int
customer_df = customer_df.rename(columns={"id":"customer_id"}) 
combined_transactions['customer_id']=combined_transactions.customer_id.astype(str)

# %% [markdown]
# # RFM calculation & Custom Heuristics
#
# - Recency :
#
#     1. Calculate the last datetime and use it instead of present datetime
#     2. Calculate the number of days from overall last orderdate of the entire transaction dataframe
#     3. Recency score is inversely proportional to number of days
#
#
# - Frequency :
#     1. For each customer check how many times they placed an order (each order id)
#     2. Could be over different dates
#     3. Quantity of items bought not taken into account
#
#
# - Monetary :
#     1. Calculate mean of the revenue bought in by each customer over entire transaction date = avg sales attributed to a customer
#
#
# - Parameters considered :
#     1. accepts marketing = true
#     2. orders_count > 1
#     3. verified email = true
#
#
# ## Merging
# - Merge customer_loyalty_df with customer_df to get a final_output_df of the customers who fulfill the parameters considered.
# - Merge final_output_df with merchandise_df to match the product ids of the various orders to products

# %%
#assuming that the transactions are always updated

#we use the last date in transactions for the recency calculation instead of using the present date, to relatively balance the recency values
last_date_time_in_transactions = combined_transactions['order_date'].max() + timedelta(days=1)

#need ways to optimize this function/calculation for a large dataframe it would take a long time
#for starters, using batching to divide the data into small batches while doing this calculation
rfm = combined_transactions.groupby(['customer_id']).agg({'order_date': lambda x: (last_date_time_in_transactions - x.max()).days,
                                                                             'order_id': 'count',
                                                                             'revenue': 'mean'})
rfm.rename(columns = {'order_date': '#days_since_last_order',
                     'order_id': 'frequency',
                     'revenue': 'avg_monetary_value'}, inplace=True)

#changing the index of customer-ids into a column
rfm = rfm.reset_index(level=['customer_id'])

# %%
rfm
# Out:
#           customer_id  #days_since_last_order  frequency  avg_monetary_value
# 0       1000000028746                     849          1               115.0
# 1       1000000290890                     849          1                72.0
# 2       1000000880714                     849          1               230.0
# 3       1000001568842                     849          1                 7.0
# 4       1000003371082                     849          1               115.0
# ...               ...                     ...        ...                 ...
# 774509   999976304714                     503          2                98.5
# 774510   999980957770                      91          4                55.5
# 774511   999991050314                     849          1               105.0
# 774512   999997669450                     849          1               105.0
# 774513   999999504458                     849          2                63.5
#
# [774514 rows x 4 columns]

# %%
rfm
# Out:
#             customer_id  frequency  order_id  avg_monetary_value
# 0       #17029090181194        206         1                87.0
# 1       #17032455553098        206         1               210.0
# 2       #17042727403594        206         1                75.0
# 3       #17065714057290        206         1               500.0
# 4       #17071264792650        206         1               105.0
# ...                 ...        ...       ...                 ...
# 774638     999976304714        503         2                98.5
# 774639     999980957770         91         4                55.5
# 774640     999991050314        849         1               105.0
# 774641     999997669450        849         1               105.0
# 774642     999999504458        849         2                63.5
#
# [774643 rows x 4 columns]

# %%
r_score_range = range(1,6)
#f_score_range = range(1,3)
m_score_range = range(1,4)

r_score = pd.qcut(rfm['#days_since_last_order'], q=5, labels=r_score_range)

#q=5 for frequency because otherwise it doesn't split the distribution into two groups
#f_score = pd.qcut(rfm['frequency'], q=10, labels=f_score_range, duplicates='drop')

#taking frequency directly instead of qcutting it

m_score = pd.qcut(rfm['avg_monetary_value'], q=3, labels=m_score_range, duplicates='drop')

#'R_rev' because higher number of days reflects lower recency score 
rfm_with_labels = rfm.assign(R_rev = r_score.values, M = m_score.values)

#converting all the columns to int
cols = ['R_rev','frequency','M']
rfm_with_labels[cols]=rfm_with_labels[cols].apply(pd.to_numeric, errors="raise", axis=1)

#adjusting the R score
rfm_with_labels['R'] = 6 - rfm_with_labels['R_rev']

#adding RFM scores
rfm_with_labels['loyalty_score'] = rfm_with_labels[['R', 'frequency', 'M']].sum(axis=1)

#cleaning up the final dataframe
rfm_with_score = rfm_with_labels.reset_index()
customer_loyalty_df = rfm_with_score.drop(['index','R_rev'], axis = 1)

# %%
#setting up custom heuristics
customer_loyalty_df['customer_id'] = customer_loyalty_df.customer_id.astype(str)

#input for custom heuristic
#when customer_df and customer_loyalty_df are merged, all customer_ids (current customers) are expected to be present in the customer_df
custom_heuristic_input_df = pd.merge(customer_loyalty_df, customer_df, on='customer_id', how='left')

#the three heuristic rules
custom_heuristic_output_df = custom_heuristic_input_df.loc[custom_heuristic_input_df['orders_count']>1]
custom_heuristic_output_df = custom_heuristic_output_df[custom_heuristic_output_df['accepts_marketing']==True]
custom_heuristic_output_df = custom_heuristic_output_df[custom_heuristic_output_df['verified_email']==True]

#output
custom_heuristic_output_df = custom_heuristic_output_df.reset_index()
final_output_df = custom_heuristic_output_df.drop(['index'],axis=1)

# %%
final_output_df
# Out:
#         customer_id  #days_since_last_order  frequency  avg_monetary_value  M  \
# 0     3893916467274                     163          4          101.500000  2
# 1     3893928722506                     129          4           85.750000  2
# 2     3893943894090                     184          7           20.285714  1
# 3     3893965029450                     142          2          115.000000  3
# 4     3893975646282                     112          4           93.250000  2
# ...             ...                     ...        ...                 ... ..
# 2932  5083002994762                      79          4           87.500000  2
# 2933  5083456569418                      79          6           47.000000  1
# 2934  5084289564746                      75         16           91.500000  2
# 2935  5084759785546                      77          4          115.000000  3
# 2936  5085681320010                      77          8           85.000000  2
#
#       R  loyalty_score accepts_marketing  orders_count  total_spent  \
# 0     4             10              True           2.0       223.00
# 1     4             10              True           2.0       240.08
# 2     4             12              True           2.0        32.80
# 3     4              9              True           2.0       243.80
# 4     5             11              True           2.0       237.23
# ...  ..            ...               ...           ...          ...
# 2932  5             11              True           2.0       194.20
# 2933  5             12              True           2.0       149.48
# 2934  5             23              True           2.0       423.28
# 2935  5             12              True           2.0       124.03
# 2936  5             15              True           3.0        88.83
#
#      verified_email
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 2932           True
# 2933           True
# 2934           True
# 2935           True
# 2936           True
#
# [2937 rows x 11 columns]

# %%
#matching customers with products they bought
merge_output_with_transaction_data = pd.merge(final_output_df, combined_transactions, on='customer_id', how='left')

merchandise_df['product_id'] = merchandise_df.product_id.astype(int)
merge_output_with_transaction_data['product_id'] = merge_output_with_transaction_data.product_id.astype(int)
merge_output_with_transaction_data['customer_id'] = merge_output_with_transaction_data.customer_id.astype(int)


product_loyalty_df = pd.merge(merge_output_with_transaction_data, merchandise_df, how='left', left_on = ['customer_id','product_id'],right_on=['product_id'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-9a6f1fdc928d> in <module>
#       8
#       9
# ---> 10 product_loyalty_df = pd.merge(merge_output_with_transaction_data, merchandise_df, how='left', left_on = ['customer_id','product_id'],right_on=['product_id'])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1337                 self.left_on = [None] * n
#    1338         if self.how != "cross" and len(self.right_on) != len(self.left_on):
# -> 1339             raise ValueError("len(right_on) must equal len(left_on)")
#    1340
#    1341     def _validate(self, validate: str):
#
# ValueError: len(right_on) must equal len(left_on)

# %%
merchandise_df
# Out:
#           variant_id     product_id  category_id            variant_name  \
# 0     32552653881418  4810467541066     Aluminum                    Both
# 1     32663668752458  4900303536202  Accessories                   Burnt
# 2     32663675174986  4900303536202  Accessories                  Carbon
# 3     29021750689866  3737038782538     Aluminum              Cash Strap
# 4     29021750722634  3737038782538     Aluminum              Money Clip
# ...              ...            ...          ...                     ...
# 1895             702  3712449806410    Gift Card  Replacement Money Clip
# 1896             703  3712449806410    Gift Card          T5 Torx Driver
# 1897             711  3712449806410    Gift Card       Both Bundle Items
# 1898             507  4672560955466     Aluminum              Cash Strap
# 1899             508  4672560955466     Aluminum              Money Clip
#
#                 product_name category_name  original_price  \
# 0       18 KARAT GOLD PLATED      Aluminum           225.0
# 1              Accessory Kit   Accessories            54.0
# 2              Accessory Kit   Accessories            54.0
# 3     Aluminum - Matte White      Aluminum            85.0
# 4     Aluminum - Matte White      Aluminum            85.0
# ...                      ...           ...             ...
# 1895            Wallet Parts     Gift Card             0.0
# 1896            Wallet Parts     Gift Card             0.0
# 1897            Wallet Parts     Gift Card            12.0
# 1898           Woodland Camo      Aluminum            85.0
# 1899           Woodland Camo      Aluminum            85.0
#
#                                              image_link
# 0     https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1     https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 2     https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 3     https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 4     https://cdn.shopify.com/s/files/1/0613/6213/pr...
# ...                                                 ...
# 1895  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1896  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1897  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1898  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1899  https://cdn.shopify.com/s/files/1/0613/6213/pr...
#
# [1900 rows x 8 columns]

# %%
product_loyalty_df.to_excel('prd.xlsx')
# Out:
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/burnt-collection_f5bca21b-2e1b-4600-95e3-4da27de973fc.jpg?v=1617139677' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/cavity-tray-3.jpg?v=1604696953' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/NEW-RENDERS_Collection_template_damascus.jpg?v=1609888123' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/damascus-collection.jpg?v=1620329459' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black_lightning-usb_1.jpg?v=1612302599' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black_micro-usb_1.jpg?v=1612302810' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/collection-topo.jpg?v=1616625086' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/NEW-RENDERS_Collection_template-18k.jpg?v=1609887933' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/NEW-RENDERS_Collection_forged-exclusive.png?v=1607630110' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/NEW-RENDERS_Collection_template_stonewashed.jpg?v=1611253925' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/xr_black_1.jpg?v=1570467907' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/Money_clip_black_1_f8a34513-8f80-4aa4-b3cc-c2f4bd6887b0.jpg?v=1590616112' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/brown_1.jpg?v=1600123078' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/travel_bag_front.jpg?v=1581532635' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black1_ddb82e76-c610-4f2a-a560-22100699ff93.jpg?v=1617732566' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/collection_black_35c09905-ab51-40a7-8cd6-394ee1251802.jpg?v=1608251257' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/NEW-RENDERS_Collection_ti-cobalt.jpg?v=1607630350' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/accessory-variant-3-burnta.jpg?v=1613169993' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/tropical_1500x1500.png?v=1588988985' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/trekke2_6e331587-c510-4c59-bfca-d6cfb4608416.jpg?v=1581039881' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/bandana_images2.jpg?v=1587504693' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/cavity-tray-3_eb31adad-80ae-49d4-bd6e-8661ed6c5089.jpg?v=1614038109' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black_typec-usb_1.jpg?v=1612303772' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black_typec-c_1.jpg?v=1612303570' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/collection-tiki.jpg?v=1616624855' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/collection-white.jpg?v=1616623463' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/forged-collection-new.jpg?v=1616612662' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/beanies-2.jpg?v=1602113037' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/iPhone12-mini-brown.jpg?v=1605298640' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/stickerpack-5.jpg?v=1607472416' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/hook-1.png?v=1588987799' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/20210202_walletinsuranceArtboard1_f316fe94-a2da-4944-87f3-63484f58d97b.jpg?v=1612812469' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/iPhone11-Brown_new_7e434537-0b50-4664-b3f4-b2d454f687cc.jpg?v=1573859872' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/ripstop_blue_front.jpg?v=1583950656' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/daypack-blue-front.jpg?v=1585007499' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/x-xs_black_1.jpg?v=1569959459' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/20210202_walletinsuranceArtboard1_4e1ad3a9-2460-42ae-ad2d-437ec00531e8.jpg?v=1612812487' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/weatherproof-front.jpg?v=1583181731' since it exceeds Excel's limit of 65,530 URLS per worksheet.
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/6.7-2.jpg?v=1620251153' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/koozie1_copy.jpg?v=1587575356' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/20210202_walletinsuranceArtboard1.jpg?v=1612896094' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/1expedition1.jpg?v=1573161100' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/hat-black-1.jpg?v=1606155004' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black_back.jpg?v=1574120907' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/black_plates.jpg?v=1588621514' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/commuter-blue-front.jpg?v=1585182618' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:919: UserWarning:
#
# Ignoring URL 'https://cdn.shopify.com/s/files/1/0613/6213/products/blue_travel-front.jpg?v=1583184014' since it exceeds Excel's limit of 65,530 URLS per worksheet.

# %%
merge_output_with_transaction_data
# Out:
#          customer_id  #days_since_last_order  frequency  avg_monetary_value_x  \
# 0      3893916467274                     163          4                101.50
# 1      3893916467274                     163          4                101.50
# 2      3893916467274                     163          4                101.50
# 3      3893916467274                     163          4                101.50
# 4      3893928722506                     129          4                 85.75
# ...              ...                     ...        ...                   ...
# 15241  5085681320010                      77          8                 85.00
# 15242  5085681320010                      77          8                 85.00
# 15243  5085681320010                      77          8                 85.00
# 15244  5085681320010                      77          8                 85.00
# 15245  5085681320010                      77          8                 85.00
#
#        M  R  loyalty_score accepts_marketing  orders_count  total_spent  \
# 0      2  4             10              True           2.0       223.00
# 1      2  4             10              True           2.0       223.00
# 2      2  4             10              True           2.0       223.00
# 3      2  4             10              True           2.0       223.00
# 4      2  4             10              True           2.0       240.08
# ...   .. ..            ...               ...           ...          ...
# 15241  2  5             15              True           3.0        88.83
# 15242  2  5             15              True           3.0        88.83
# 15243  2  5             15              True           3.0        88.83
# 15244  2  5             15              True           3.0        88.83
# 15245  2  5             15              True           3.0        88.83
#
#       verified_email       order_id     product_id variant_id  \
# 0               True  2994887065674  4497685643338       R913
# 1               True  2994887065674  3795636617290        615
# 2               True  3029780627530  4497685643338       R913
# 3               True  3029780627530  3795636617290        615
# 4               True  3646916558922  4725951463498        509
# ...              ...            ...            ...        ...
# 15241           True  3722026614858      347698423        232
# 15242           True  3721982148682      347698423        232
# 15243           True  3721974317130      347698423        232
# 15244           True  3722026614858      347698423        232
# 15245           True  3722026614858      347698423        232
#
#                  source_id       store_id order_date  selling_price  quantity  \
# 0                      web  1997985808458 2021-01-01           28.0         1
# 1                      web  1997985808458 2021-01-01          175.0         1
# 2      shopify draft order           None 2021-01-27           28.0         1
# 3      shopify draft order           None 2021-01-27          175.0         1
# 4                      web  2696761802826 2021-03-02          105.0         1
# ...                    ...            ...        ...            ...       ...
# 15241                  web  2696761802826 2021-04-23           85.0         1
# 15242                  web  2696761802826 2021-04-23           85.0         1
# 15243                  web  2696761802826 2021-04-23           85.0         1
# 15244                  web  2696761802826 2021-04-23           85.0         1
# 15245                  web  2696761802826 2021-04-23           85.0         1
#
#       currency  client_id  revenue shipping_zip  avg_monetary_value_y
# 0          USD         59     28.0        04870                     1
# 1          USD         59    175.0        04870                     1
# 2          USD         59     28.0        04870                     1
# 3          USD         59    175.0        04870                     1
# 4          USD         59    105.0        85296                     1
# ...        ...        ...      ...          ...                   ...
# 15241      USD         59     85.0        96701                     1
# 15242      USD         59     85.0        96701                     1
# 15243      USD         59     85.0        96701                     1
# 15244      USD         59     85.0        96701                     1
# 15245      USD         59     85.0        96701                     1
#
# [15246 rows x 24 columns]

# %%
#merge_output_with_transaction_data.to_excel('mrg.xlsx')

# %% [markdown]
# # Plots
#
# 1. Use customer_loyalty_df for loyalty level distribution

# %%
rfm.loc[rfm['customer_id']=="3778760212554"].head(50)
# Out:
#           customer_id  frequency  avg_monetary_value
# 442785  3778760212554         41           344.02439

# %% [markdown]
# ## Analysing the data
#
# - Checking for a particular customer - how to calculate average order value
#     - There seems to be multiple orders for a certain order_date by the same customer

# %%
combined_transactions.loc[combined_transactions['customer_id']=="3778760212554"].head(100)
# Out:
#              order_id     product_id variant_id    customer_id  \
# 2       2975452364874      347692039        442  3778760212554
# 3       2975452364874    90267582478        282  3778760212554
# 82953   2920320041034      347698423        232  3778760212554
# 82954   2920320041034    90267582478        282  3778760212554
# 82955   2920320041034    11471829006       S262  3778760212554
# 84090   2918329155658    11471829006       S262  3778760212554
# 84091   2918329155658      347698423        232  3778760212554
# 84092   2918329155658    90267582478        282  3778760212554
# 84093   2918329155658      347148895       S222  3778760212554
# 211115  2907921711178    90267582478        282  3778760212554
# 324513  2889766502474      347698423       K272  3778760212554
# 324514  2889766502474    11471829006       K273  3778760212554
# 324515  2889766502474      347148895        603  3778760212554
# 324516  2889766502474      347692039       K254  3778760212554
# 324517  2889766502474  3798739451978       K233  3778760212554
# 324518  2889766502474  4429522108490       K274  3778760212554
# 324519  2889766502474      347698423        232  3778760212554
# 324520  2889766502474      347148895        222  3778760212554
# 535495  3013434376266      347698423        231  3778760212554
# 535496  3013434376266      347698423        232  3778760212554
# 535497  3013434376266    11471829006        261  3778760212554
# 535498  3013434376266    11471829006        262  3778760212554
# 535499  3013434376266      347688939        311  3778760212554
# 535500  3013434376266      347688939        312  3778760212554
# 535501  3013434376266      347692039        441  3778760212554
# 535502  3013434376266      347692039        442  3778760212554
# 788870  3060376567882      347701067        212  3778760212554
# 788871  3060376567882      347698423        232  3778760212554
# 788872  3060376567882      347148895        222  3778760212554
# 798045  2907529642058    90267582478        282  3778760212554
# 798046  2907529642058      347698423        232  3778760212554
# 798047  2907529642058    11471829006       S262  3778760212554
# 798048  2907529642058      347148895       S222  3778760212554
# 1898    3791191572554  4810467541066        616  3778760212554
# 1899    3791191572554      347698423        232  3778760212554
# 1900    3791191572554    11471829006        262  3778760212554
# 1901    3791191572554    90267582478        282  3778760212554
# 1902    3791191572554  3795636617290        615  3778760212554
# 1903    3791191572554      347701067        212  3778760212554
# 1904    3791191572554      347148895        222  3778760212554
# 3616    3792208166986      347701067        212  3778760212554
#
#                   source_id       store_id order_date  selling_price  \
# 2                       web  1997985808458 2020-12-16          125.0
# 3                       web  1997985808458 2020-12-16           75.0
# 82953                   web  1997985808458 2020-11-20           75.0
# 82954                   web  1997985808458 2020-11-20           75.0
# 82955                   web  1997985808458 2020-11-20           75.0
# 84090                   web  1997985808458 2020-11-19           75.0
# 84091                   web  1997985808458 2020-11-19           75.0
# 84092                   web  1997985808458 2020-11-19           75.0
# 84093                   web  1997985808458 2020-11-19           75.0
# 211115  shopify draft order           None 2020-11-12           75.0
# 324513                  web  1997985808458 2020-10-31           87.0
# 324514                  web  1997985808458 2020-10-31           87.0
# 324515                  web  1997985808458 2020-10-31           87.0
# 324516                  web  1997985808458 2020-10-31          137.0
# 324517                  web  1997985808458 2020-10-31          137.0
# 324518                  web  1997985808458 2020-10-31          117.0
# 324519                  web  1997985808458 2020-10-31           75.0
# 324520                  web  1997985808458 2020-10-31           75.0
# 535495                  web  1997985808458 2021-01-14           75.0
# 535496                  web  1997985808458 2021-01-14           75.0
# 535497                  web  1997985808458 2021-01-14           75.0
# 535498                  web  1997985808458 2021-01-14           75.0
# 535499                  web  1997985808458 2021-01-14          105.0
# 535500                  web  1997985808458 2021-01-14          105.0
# 535501                  web  1997985808458 2021-01-14          125.0
# 535502                  web  1997985808458 2021-01-14          125.0
# 788870                  web  2696761802826 2021-02-20           75.0
# 788871                  web  2696761802826 2021-02-20           75.0
# 788872                  web  2696761802826 2021-02-20           75.0
# 798045                  web  1997985808458 2020-11-12           75.0
# 798046                  web  1997985808458 2020-11-12           75.0
# 798047                  web  1997985808458 2020-11-12           75.0
# 798048                  web  1997985808458 2020-11-12           75.0
# 1898                    web  2696761802826 2021-06-07          225.0
# 1899                    web  2696761802826 2021-06-07           85.0
# 1900                    web  2696761802826 2021-06-07           85.0
# 1901                    web  2696761802826 2021-06-07           85.0
# 1902                    web  2696761802826 2021-06-07          175.0
# 1903                    web  2696761802826 2021-06-07           85.0
# 1904                    web  2696761802826 2021-06-07           85.0
# 3616    shopify draft order           None 2021-06-08           85.0
#
#         quantity currency  client_id  revenue shipping_zip
# 2              6      USD         59    750.0        73069
# 3              6      USD         59    450.0        73069
# 82953         15      USD         59   1125.0        73069
# 82954          4      USD         59    300.0        73069
# 82955          5      USD         59    375.0        73069
# 84090         20      USD         59   1500.0        73069
# 84091         10      USD         59    750.0        73069
# 84092          5      USD         59    375.0        73069
# 84093          2      USD         59    150.0        73069
# 211115         4      USD         59    300.0        73069
# 324513         3      USD         59    261.0        73069
# 324514         2      USD         59    174.0        73069
# 324515         2      USD         59    174.0        73069
# 324516         1      USD         59    137.0        73069
# 324517         1      USD         59    137.0        73069
# 324518         1      USD         59    117.0        73069
# 324519         1      USD         59     75.0        73069
# 324520         1      USD         59     75.0        73069
# 535495         3      USD         59    225.0        73069
# 535496         3      USD         59    225.0        73069
# 535497         3      USD         59    225.0        73069
# 535498         3      USD         59    225.0        73069
# 535499         1      USD         59    105.0        73069
# 535500         1      USD         59    105.0        73069
# 535501         1      USD         59    125.0        73069
# 535502         1      USD         59    125.0        73069
# 788870         9      USD         59    675.0        73069
# 788871         3      USD         59    225.0        73069
# 788872         3      USD         59    225.0        73069
# 798045         4      USD         59    300.0        73069
# 798046         4      USD         59    300.0        73069
# 798047         4      USD         59    300.0        73069
# 798048         2      USD         59    150.0        73069
# 1898           2      USD         59    450.0        73069
# 1899          10      USD         59    850.0        73069
# 1900          10      USD         59    850.0        73069
# 1901           3      USD         59    255.0        73069
# 1902           1      USD         59    175.0        73069
# 1903           3      USD         59    255.0        73069
# 1904           3      USD         59    255.0        73069
# 3616           3      USD         59    255.0        73069

# %%
#rfm score check - 'recency'
#no of days = 849, while calculating recency
#low recency score
combined_transactions.loc[combined_transactions['customer_id']=="999991050314"].head(50)
# Out:
#             order_id   product_id variant_id   customer_id source_id  \
# 790577  859213758538  11361067278        332  999991050314       web
#
#             store_id order_date  selling_price  quantity currency  client_id  \
# 790577  796006023242 2019-03-13          105.0         1      USD         59
#
#         revenue shipping_zip
# 790577    105.0        60657

# %%
#rfm score check - 'recency'
#no of days = 91 , while calculating recency
#high recency score
combined_transactions.loc[combined_transactions['customer_id']=="999980957770"].head(50)
# Out:
#              order_id     product_id variant_id   customer_id source_id  \
# 282892  2904745705546  4810375757898        C66  999980957770       web
# 420535  3701402173514  4810375757898        C66  999980957770   4072793
# 790578   859203993674      347148895        222  999980957770       web
# 1083    3701402173514  4810375757898        C66  999980957770   4072793
#
#              store_id order_date  selling_price  quantity currency  client_id  \
# 282892  1997985808458 2020-11-10           50.0         1      USD         59
# 420535           None 2021-04-09           50.0         1      USD         59
# 790578   796006023242 2019-03-13           72.0         1      USD         59
# 1083             None 2021-04-09           50.0         1      USD         59
#
#         revenue shipping_zip
# 282892     50.0        46835
# 420535     50.0        46835
# 790578     72.0        46835
# 1083       50.0        46835

# %%
#what item did customer_id - 999980957770 repeatedly buy? = phone cases
merchandise_df.loc[merchandise_df['product_id']=='4810375757898']
# Out:
#           variant_id     product_id category_id         variant_name  \
# 64    32551106248778  4810375757898  Phone Case      Brown / 12 Mini
# 65    32551106281546  4810375757898  Phone Case      Black / 12 Mini
# 66    32551106314314  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 67    32551106347082  4810375757898  Phone Case  Black / 12 / 12 Pro
# 68    32551106379850  4810375757898  Phone Case   Brown / 12 Pro Max
# 69    32551106412618  4810375757898  Phone Case   Black / 12 Pro Max
# 251   32551106248778  4810375757898  Phone Case      Brown / 12 Mini
# 252   32551106281546  4810375757898  Phone Case      Black / 12 Mini
# 253   32551106314314  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 254   32551106347082  4810375757898  Phone Case  Black / 12 / 12 Pro
# 255   32551106379850  4810375757898  Phone Case   Brown / 12 Pro Max
# 256   32551106412618  4810375757898  Phone Case   Black / 12 Pro Max
# 447              C64  4810375757898  Phone Case      Brown / 12 Mini
# 448              C63  4810375757898  Phone Case      Black / 12 Mini
# 449              C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 450              C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 451              C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 452              C67  4810375757898  Phone Case   Black / 12 Pro Max
# 643              C64  4810375757898  Phone Case      Brown / 12 Mini
# 644              C63  4810375757898  Phone Case      Black / 12 Mini
# 645              C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 646              C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 647              C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 648              C67  4810375757898  Phone Case   Black / 12 Pro Max
# 839              C64  4810375757898  Phone Case      Brown / 12 Mini
# 840              C63  4810375757898  Phone Case      Black / 12 Mini
# 841              C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 842              C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 843              C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 844              C67  4810375757898  Phone Case   Black / 12 Pro Max
# 1029             C64  4810375757898  Phone Case      Brown / 12 Mini
# 1030             C63  4810375757898  Phone Case      Black / 12 Mini
# 1031             C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 1032             C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 1033             C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 1034             C67  4810375757898  Phone Case   Black / 12 Pro Max
# 1216             C64  4810375757898  Phone Case      Brown / 12 Mini
# 1217             C63  4810375757898  Phone Case      Black / 12 Mini
# 1218             C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 1219             C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 1220             C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 1221             C67  4810375757898  Phone Case   Black / 12 Pro Max
# 1403             C64  4810375757898  Phone Case      Brown / 12 Mini
# 1404             C63  4810375757898  Phone Case      Black / 12 Mini
# 1405             C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 1406             C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 1407             C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 1408             C67  4810375757898  Phone Case   Black / 12 Pro Max
# 1591             C64  4810375757898  Phone Case      Brown / 12 Mini
# 1592             C63  4810375757898  Phone Case      Black / 12 Mini
# 1593             C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 1594             C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 1595             C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 1596             C67  4810375757898  Phone Case   Black / 12 Pro Max
# 1777             C64  4810375757898  Phone Case      Brown / 12 Mini
# 1778             C63  4810375757898  Phone Case      Black / 12 Mini
# 1779             C66  4810375757898  Phone Case  Brown / 12 / 12 Pro
# 1780             C65  4810375757898  Phone Case  Black / 12 / 12 Pro
# 1781             C68  4810375757898  Phone Case   Brown / 12 Pro Max
# 1782             C67  4810375757898  Phone Case   Black / 12 Pro Max
#
#                    product_name category_name  original_price  \
# 64    The Card Case - iPhone 12    Phone Case            50.0
# 65    The Card Case - iPhone 12    Phone Case            50.0
# 66    The Card Case - iPhone 12    Phone Case            50.0
# 67    The Card Case - iPhone 12    Phone Case            50.0
# 68    The Card Case - iPhone 12    Phone Case            50.0
# 69    The Card Case - iPhone 12    Phone Case            50.0
# 251   The Card Case - iPhone 12    Phone Case            50.0
# 252   The Card Case - iPhone 12    Phone Case            50.0
# 253   The Card Case - iPhone 12    Phone Case            50.0
# 254   The Card Case - iPhone 12    Phone Case            50.0
# 255   The Card Case - iPhone 12    Phone Case            50.0
# 256   The Card Case - iPhone 12    Phone Case            50.0
# 447   The Card Case - iPhone 12    Phone Case            50.0
# 448   The Card Case - iPhone 12    Phone Case            50.0
# 449   The Card Case - iPhone 12    Phone Case            50.0
# 450   The Card Case - iPhone 12    Phone Case            50.0
# 451   The Card Case - iPhone 12    Phone Case            50.0
# 452   The Card Case - iPhone 12    Phone Case            50.0
# 643   The Card Case - iPhone 12    Phone Case            50.0
# 644   The Card Case - iPhone 12    Phone Case            50.0
# 645   The Card Case - iPhone 12    Phone Case            50.0
# 646   The Card Case - iPhone 12    Phone Case            50.0
# 647   The Card Case - iPhone 12    Phone Case            50.0
# 648   The Card Case - iPhone 12    Phone Case            50.0
# 839   The Card Case - iPhone 12    Phone Case            50.0
# 840   The Card Case - iPhone 12    Phone Case            50.0
# 841   The Card Case - iPhone 12    Phone Case            50.0
# 842   The Card Case - iPhone 12    Phone Case            50.0
# 843   The Card Case - iPhone 12    Phone Case            50.0
# 844   The Card Case - iPhone 12    Phone Case            50.0
# 1029  The Card Case - iPhone 12    Phone Case            50.0
# 1030  The Card Case - iPhone 12    Phone Case            50.0
# 1031  The Card Case - iPhone 12    Phone Case            50.0
# 1032  The Card Case - iPhone 12    Phone Case            50.0
# 1033  The Card Case - iPhone 12    Phone Case            50.0
# 1034  The Card Case - iPhone 12    Phone Case            50.0
# 1216  The Card Case - iPhone 12    Phone Case            50.0
# 1217  The Card Case - iPhone 12    Phone Case            50.0
# 1218  The Card Case - iPhone 12    Phone Case            50.0
# 1219  The Card Case - iPhone 12    Phone Case            50.0
# 1220  The Card Case - iPhone 12    Phone Case            50.0
# 1221  The Card Case - iPhone 12    Phone Case            50.0
# 1403  The Card Case - iPhone 12    Phone Case            50.0
# 1404  The Card Case - iPhone 12    Phone Case            50.0
# 1405  The Card Case - iPhone 12    Phone Case            50.0
# 1406  The Card Case - iPhone 12    Phone Case            50.0
# 1407  The Card Case - iPhone 12    Phone Case            50.0
# 1408  The Card Case - iPhone 12    Phone Case            50.0
# 1591  The Card Case - iPhone 12    Phone Case            50.0
# 1592  The Card Case - iPhone 12    Phone Case            50.0
# 1593  The Card Case - iPhone 12    Phone Case            50.0
# 1594  The Card Case - iPhone 12    Phone Case            50.0
# 1595  The Card Case - iPhone 12    Phone Case            50.0
# 1596  The Card Case - iPhone 12    Phone Case            50.0
# 1777  The Card Case - iPhone 12    Phone Case            50.0
# 1778  The Card Case - iPhone 12    Phone Case            50.0
# 1779  The Card Case - iPhone 12    Phone Case            50.0
# 1780  The Card Case - iPhone 12    Phone Case            50.0
# 1781  The Card Case - iPhone 12    Phone Case            50.0
# 1782  The Card Case - iPhone 12    Phone Case            50.0
#
#                                              image_link
# 64    https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 65    https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 66    https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 67    https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 68    https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 69    https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 251   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 252   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 253   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 254   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 255   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 256   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 447   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 448   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 449   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 450   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 451   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 452   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 643   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 644   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 645   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 646   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 647   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 648   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 839   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 840   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 841   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 842   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 843   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 844   https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1029  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1030  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1031  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1032  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1033  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1034  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1216  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1217  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1218  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1219  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1220  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1221  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1403  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1404  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1405  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1406  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1407  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1408  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1591  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1592  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1593  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1594  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1595  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1596  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1777  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1778  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1779  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1780  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1781  https://cdn.shopify.com/s/files/1/0613/6213/pr...
# 1782  https://cdn.shopify.com/s/files/1/0613/6213/pr...

# %%
# frequency check
# order date for customer id 999976304714 = 503 = number of days since last purchase
# order_id = 2 = how frequently they bought items
combined_transactions.loc[combined_transactions['customer_id']=="999976304714"].head(50)
# Out:
#              order_id   product_id variant_id   customer_id source_id  \
# 643792   859200651338  90266435598        271  999976304714       web
# 849516  2175442092106    347692039        442  999976304714       web
#
#             store_id order_date  selling_price  quantity currency  client_id  \
# 643792  796006023242 2019-03-13           72.0         1      USD         59
# 849516  796006023242 2020-02-22          125.0         1      USD         59
#
#         revenue shipping_zip
# 643792     72.0   89011-2407
# 849516    125.0   89011-2407

# %%
combined_transactions
# Out:
#            order_id     product_id variant_id    customer_id source_id  \
# 0     2975528452170  3798739451978        443  3874371567690       web
# 1     2975482183754      347692039       K254  3874330476618       web
# 2     2975452364874      347692039        442  3778760212554       web
# 3     2975452364874    90267582478        282  3778760212554       web
# 4     2975444926538  3798739451978        444  3874301509706       web
# ...             ...            ...        ...            ...       ...
# 1839  3758043955274      347698423        231  5114385236042       web
# 1840  3722800758858  3795636617290        615  5086285430858       web
# 1841  3690327081034  3795636617290        615  3366304219210       web
# 1842  3690327081034  4826176749642       R139  3366304219210       web
# 1843  3690327081034  4328645460042       R906  3366304219210       web
#
#            store_id order_date  selling_price  quantity currency  client_id  \
# 0     1997985808458 2020-12-16          125.0         1      USD         59
# 1     1997985808458 2020-12-16          137.0         1      USD         59
# 2     1997985808458 2020-12-16          125.0         6      USD         59
# 3     1997985808458 2020-12-16           75.0         6      USD         59
# 4     1997985808458 2020-12-16          125.0         1      USD         59
# ...             ...        ...            ...       ...      ...        ...
# 1839  2696761802826 2021-05-20           85.0         1      USD         59
# 1840  2696761802826 2021-04-24          175.0         1      USD         59
# 1841  2696761802826 2021-04-01          175.0         1      USD         59
# 1842  2696761802826 2021-04-01           15.0         1      USD         59
# 1843  2696761802826 2021-04-01           28.0         1      USD         59
#
#       revenue shipping_zip
# 0       125.0        34291
# 1       137.0        96003
# 2       750.0        73069
# 3       450.0        73069
# 4       125.0        78665
# ...       ...          ...
# 1839     85.0        77372
# 1840    175.0        08820
# 1841    175.0        46835
# 1842     15.0        46835
# 1843     28.0        46835
#
# [1132442 rows x 13 columns]

# %%
merge_output_with_transaction_data.loc[merge_output_with_transaction_data['customer_id']=="3893916467274"].head(10)
# Out:
# Empty DataFrame
# Columns: [customer_id, #days_since_last_order, frequency, avg_monetary_value_x, M, R, loyalty_score, accepts_marketing, orders_count, total_spent, verified_email, order_id, product_id, variant_id, source_id, store_id, order_date, selling_price, quantity, currency, client_id, revenue, shipping_zip, avg_monetary_value_y]
# Index: []

# %%
combined_transactions
# Out:
#            order_id     product_id variant_id    customer_id source_id  \
# 0     2975528452170  3798739451978        443  3874371567690       web
# 1     2975482183754      347692039       K254  3874330476618       web
# 2     2975452364874      347692039        442  3778760212554       web
# 3     2975452364874    90267582478        282  3778760212554       web
# 4     2975444926538  3798739451978        444  3874301509706       web
# ...             ...            ...        ...            ...       ...
# 1839  3758043955274      347698423        231  5114385236042       web
# 1840  3722800758858  3795636617290        615  5086285430858       web
# 1841  3690327081034  3795636617290        615  3366304219210       web
# 1842  3690327081034  4826176749642       R139  3366304219210       web
# 1843  3690327081034  4328645460042       R906  3366304219210       web
#
#            store_id order_date  selling_price  quantity currency  client_id  \
# 0     1997985808458 2020-12-16          125.0         1      USD         59
# 1     1997985808458 2020-12-16          137.0         1      USD         59
# 2     1997985808458 2020-12-16          125.0         6      USD         59
# 3     1997985808458 2020-12-16           75.0         6      USD         59
# 4     1997985808458 2020-12-16          125.0         1      USD         59
# ...             ...        ...            ...       ...      ...        ...
# 1839  2696761802826 2021-05-20           85.0         1      USD         59
# 1840  2696761802826 2021-04-24          175.0         1      USD         59
# 1841  2696761802826 2021-04-01          175.0         1      USD         59
# 1842  2696761802826 2021-04-01           15.0         1      USD         59
# 1843  2696761802826 2021-04-01           28.0         1      USD         59
#
#       revenue shipping_zip
# 0       125.0        34291
# 1       137.0        96003
# 2       750.0        73069
# 3       450.0        73069
# 4       125.0        78665
# ...       ...          ...
# 1839     85.0        77372
# 1840    175.0        08820
# 1841    175.0        46835
# 1842     15.0        46835
# 1843     28.0        46835
#
# [1132442 rows x 13 columns]

# %%
l = [["a", 12, 12], [None, 12.3, 33.], ["b", 12.3, 123], ["a", 1, 1]]
df = pd.DataFrame(l, columns=["a", "b", "c"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71ea729694c7> in <module>
#       1 l = [["a", 12, 12], [None, 12.3, 33.], ["b", 12.3, 123], ["a", 1, 1]]
# ----> 2 df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# NameError: name 'pd' is not defined
